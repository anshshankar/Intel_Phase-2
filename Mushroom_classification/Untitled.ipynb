# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("mushrooms.csv")

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
df['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
df['cap-shape'].unique()
# Out:
# array(['x', 'b', 's', 'f', 'k', 'c'], dtype=object)

# %%
for col in df.columns:
    print("Column Name: ", col, df[col].unique())
# Out:
# Column Name:  class ['p' 'e']
# Column Name:  cap-shape ['x' 'b' 's' 'f' 'k' 'c']
# Column Name:  cap-surface ['s' 'y' 'f' 'g']
# Column Name:  cap-color ['n' 'y' 'w' 'g' 'e' 'p' 'b' 'u' 'c' 'r']
# Column Name:  bruises ['t' 'f']
# Column Name:  odor ['p' 'a' 'l' 'n' 'f' 'c' 'y' 's' 'm']
# Column Name:  gill-attachment ['f' 'a']
# Column Name:  gill-spacing ['c' 'w']
# Column Name:  gill-size ['n' 'b']
# Column Name:  gill-color ['k' 'n' 'g' 'p' 'w' 'h' 'u' 'e' 'b' 'r' 'y' 'o']
# Column Name:  stalk-shape ['e' 't']
# Column Name:  stalk-root ['e' 'c' 'b' 'r' '?']
# Column Name:  stalk-surface-above-ring ['s' 'f' 'k' 'y']
# Column Name:  stalk-surface-below-ring ['s' 'f' 'y' 'k']
# Column Name:  stalk-color-above-ring ['w' 'g' 'p' 'n' 'b' 'e' 'o' 'c' 'y']
# Column Name:  stalk-color-below-ring ['w' 'p' 'g' 'b' 'n' 'e' 'y' 'o' 'c']
# Column Name:  veil-type ['p']
# Column Name:  veil-color ['w' 'n' 'o' 'y']
# Column Name:  ring-number ['o' 't' 'n']
# Column Name:  ring-type ['p' 'e' 'l' 'f' 'n']
# Column Name:  spore-print-color ['k' 'n' 'u' 'h' 'w' 'r' 'o' 'y' 'b']
# Column Name:  population ['s' 'n' 'a' 'v' 'y' 'c']
# Column Name:  habitat ['u' 'g' 'm' 'd' 'p' 'w' 'l']

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# top                         w                      w         p          w
# freq                     4464                   4384      8124       7924
#
#        ring-number ring-type spore-print-color population habitat
# count         8124      8124              8124       8124    8124
# unique           3         5                 9          6       7
# top              o         p                 w          v       d
# freq          7488      3968              2388       4040    3148
#
# [4 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
# Encoding Values

from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
for col in df.columns:
    df[col] = labelencoder.fit_transform(df[col])
 
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            1          4                  2           3        5
# 1            1          4                  3           2        1
# 2            1          4                  3           2        3
# 3            1          4                  2           3        5
# 4            1          0                  3           0        1
#
# [5 rows x 23 columns]

# %%
# Seperating the labels

X = df.iloc[:,1:23]  # all rows, all the features and no labels
y = df.iloc[:, 0]  # all rows, label only
X.head()
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: class, dtype: int64

# %%
plt.figure(figsize=(18,15))
sns.heatmap(df.corr(),annot=True,cmap='viridis')
plt.show()

# %%
# Standardizing the data

# Scale the data to be between -1 and 1
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X=scaler.fit_transform(X)
X
# Out:
# array([[ 1.02971224,  0.14012794, -0.19824983, ..., -0.67019486,
#         -0.5143892 ,  2.03002809],
#        [ 1.02971224,  0.14012794,  1.76587407, ..., -0.2504706 ,
#         -1.31310821, -0.29572966],
#        [-2.08704716,  0.14012794,  1.37304929, ..., -0.2504706 ,
#         -1.31310821,  0.86714922],
#        ...,
#        [-0.8403434 ,  0.14012794, -0.19824983, ..., -1.50964337,
#         -2.11182722,  0.28570978],
#        [-0.21699152,  0.95327039, -0.19824983, ...,  1.42842641,
#          0.28432981,  0.28570978],
#        [ 1.02971224,  0.14012794, -0.19824983, ...,  0.16925365,
#         -2.11182722,  0.28570978]])

# %%
# Test- Train Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (6093, 22)
# (2031, 22)

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression
from sklearn import metrics

model_LR= LogisticRegression()

# %%
model_LR.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, pred))
# Out:
# Accuracy: 0.9551944854751354

# %%
#confusion matrix 
cnf_matrix = metrics.confusion_matrix(y_test, pred)
cnf_matrix
# Out:
# array([[987,  53],
#        [ 38, 953]], dtype=int64)

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

Random  =  RandomForestClassifier(n_estimators= 120)

Random.fit(X_train,y_train)

y_pred =  Random.predict(X_test)

# %%
# Hold out Validation
accuracy = metrics.accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 1.0

# %%
#confusion matrix 
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[1040,    0],
#        [   0,  991]], dtype=int64)

# %%
# SUpport Vector Classifier

# %%
from sklearn.svm import SVC
svc = SVC()
svc . fit(X_train, y_train)
pred_svc = svc.predict(X_test)
accuracy_svc = metrics.accuracy_score(y_test,pred_svc)

# %%
accuracy_svc
# Out:
# 1.0

# %%
#confusion matrix 
cnf_matrix = metrics.confusion_matrix(y_test, pred_svc)
cnf_matrix
# Out:
# array([[1040,    0],
#        [   0,  991]], dtype=int64)

# %%
# Classification report for all three models

# For Logistic Regression

from sklearn.metrics import classification_report

print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      1040
#            1       0.95      0.96      0.95       991
#
#     accuracy                           0.96      2031
#    macro avg       0.96      0.96      0.96      2031
# weighted avg       0.96      0.96      0.96      2031

# %%
# For Random Forest

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1040
#            1       1.00      1.00      1.00       991
#
#     accuracy                           1.00      2031
#    macro avg       1.00      1.00      1.00      2031
# weighted avg       1.00      1.00      1.00      2031

# %%
# For SVC

print(classification_report(y_test,pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1040
#            1       1.00      1.00      1.00       991
#
#     accuracy                           1.00      2031
#    macro avg       1.00      1.00      1.00      2031
# weighted avg       1.00      1.00      1.00      2031
